# %% [markdown]
# # Reina AL MASRI, Mahmoud El Kasaby
#
# ## Baseline Model: Bigrams Bag of Words (PubMed RCT)

# %% [markdown]
# ### 1. Install and Import Libraries

# %%
# !git clone https://github.com/Franck-Dernoncourt/pubmed-rct
# Out:
# fatal: destination path 'pubmed-rct' already exists and is not an empty directory.

# %%
# !pip install scispacy
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz
import spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scispacy in /Users/reina/Library/Python/3.9/lib/python/site-packages (0.6.2)
# Requirement already satisfied: spacy<3.9.0,>=3.7.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (3.7.5)
# Requirement already satisfied: scipy in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (1.13.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (2.32.5)
# Requirement already satisfied: conllu in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy<2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (1.26.4)
# Requirement already satisfied: joblib in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (1.5.2)
# Requirement already satisfied: nmslib>=1.7.3.6 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (2.1.2)
# Requirement already satisfied: scikit-learn>=0.20.3 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (1.6.1)
# Requirement already satisfied: pysbd in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2025.10.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (2.12.5)
# Requirement already satisfied: jinja2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (3.1.5)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (58.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.9.0,>=3.7.0->scispacy) (3.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.7.0->scispacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.7.0->scispacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.7.0->scispacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.7.0->scispacy) (0.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.9.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.9.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (14.1.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.7.0->scispacy) (0.21.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.7.0->scispacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.7.0->scispacy) (7.5.0)
# Requirement already satisfied: wrapt in /Users/reina/Library/Python/3.9/lib/python/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.7.0->scispacy) (1.17.3)
# Requirement already satisfied: pybind11>=2.2.3 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from nmslib>=1.7.3.6->scispacy) (3.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.7.0->scispacy) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.20.3->scispacy) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<3.9.0,>=3.7.0->scispacy) (3.0.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz (119.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from en-core-sci-md==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.12.5)
# Requirement already satisfied: jinja2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.1.5)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (58.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.26.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2025.10.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (14.1.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.21.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (7.5.0)
# Requirement already satisfied: wrapt in /Users/reina/Library/Python/3.9/lib/python/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (1.17.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/reina/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<3.8.0,>=3.7.4->en-core-sci-md==0.5.4) (3.0.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import re
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
nlp = spacy.load("en_core_sci_md")

# %% [markdown]
# ### 2. Enhanced Scispacy Tokenizer

# %%
def scispacy_tokenizer(text):
    _punct = re.compile(r"^[\W_]+$")
    doc = nlp(text)
    tokens = []
    for t in doc:
        if t.is_space:
            continue
        if t.like_num:
            tokens.append("__NUM__")
            continue
        if t.is_stop and t.text.lower() not in {"no", "not", "without"}:
            continue
        if _punct.match(t.text):
            continue
        lemma = (t.lemma_ or t.text).lower().strip()
        if len(lemma) >= 2:
            tokens.append(lemma)
    return tokens

# %% [markdown]
# ### 3. Load PubMed RCT Dataset

# %%
def load_rct_data(file_path):
    texts, labels = [], []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.rstrip('\n')
            if line.startswith('###') or line.strip() == '':
                continue
            if '\t' in line:
                label, text = line.split('\t', 1)
                labels.append(label)
                texts.append(text)
    return texts, labels

# %%
path_rct = "pubmed-rct/PubMed_20k_RCT/"
X_train, y_train = load_rct_data(path_rct + 'train.txt')
X_test, y_test = load_rct_data(path_rct + 'test.txt')
print(f"Train: {len(X_train)}, Test: {len(X_test)}")
print(f"Labels: {sorted(set(y_train))}")
# Out:
# Train: 180040, Test: 30135
# Labels: ['BACKGROUND', 'CONCLUSIONS', 'METHODS', 'OBJECTIVE', 'RESULTS']

# %% [markdown]
# ### 4. Baseline: TF-IDF Bigrams (Bag of Words)

# %%
tfidf = TfidfVectorizer(tokenizer=scispacy_tokenizer, max_features=5000, ngram_range=(2,2))
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)
# Out:
# /Users/reina/Library/Python/3.9/lib/python/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_tfidf, y_train)
y_pred = model.predict(X_test_tfidf)
print("Bag of Words (Bigrams) accuracy:", accuracy_score(y_test, y_pred))

# %%
print(classification_report(y_test, y_pred, target_names=sorted(set(y_test))))
